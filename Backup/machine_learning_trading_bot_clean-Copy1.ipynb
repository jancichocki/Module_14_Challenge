# %% [markdown]
# # Machine Learning Trading Bot
#
# In this Challenge, you’ll assume the role of a financial advisor at one of the top five financial advisory firms in the world. Your firm constantly competes with the other major firms to manage and automatically trade assets in a highly dynamic environment. In recent years, your firm has heavily profited by using computer algorithms that can buy and sell faster than human traders.
#
# The speed of these transactions gave your firm a competitive advantage early on. But, people still need to specifically program these systems, which limits their ability to adapt to new data. You’re thus planning to improve the existing algorithmic trading systems and maintain the firm’s competitive advantage in the market. To do so, you’ll enhance the existing trading signals with machine learning algorithms that can adapt to new data.
#
# ## Instructions:
#
# Use the starter code file to complete the steps that the instructions outline. The steps for this Challenge are divided into the following sections:
#
# * Establish a Baseline Performance
#
# * Tune the Baseline Trading Algorithm
#
# * Evaluate a New Machine Learning Classifier
#
# * Create an Evaluation Report
#
# #### Establish a Baseline Performance
#
# In this section, you’ll run the provided starter code to establish a baseline performance for the trading algorithm. To do so, complete the following steps.
#
# Open the Jupyter notebook. Restart the kernel, run the provided cells that correspond with the first three steps, and then proceed to step four.
#
# 1. Import the OHLCV dataset into a Pandas DataFrame.
#
# 2. Generate trading signals using short- and long-window SMA values.
#
# 3. Split the data into training and testing datasets.
#
# 4. Use the `SVC` classifier model from SKLearn's support vector machine (SVM) learning method to fit the training data and make predictions based on the testing data. Review the predictions.
#
# 5. Review the classification report associated with the `SVC` model predictions.
#
# 6. Create a predictions DataFrame that contains columns for “Predicted” values, “Actual Returns”, and “Strategy Returns”.
#
# 7. Create a cumulative return plot that shows the actual returns vs. the strategy returns. Save a PNG image of this plot. This will serve as a baseline against which to compare the effects of tuning the trading algorithm.
#
# 8. Write your conclusions about the performance of the baseline trading algorithm in the `README.md` file that’s associated with your GitHub repository. Support your findings by using the PNG image that you saved in the previous step.
#
# #### Tune the Baseline Trading Algorithm
#
# In this section, you’ll tune, or adjust, the model’s input features to find the parameters that result in the best trading outcomes. (You’ll choose the best by comparing the cumulative products of the strategy returns.) To do so, complete the following steps:
#
# 1. Tune the training algorithm by adjusting the size of the training dataset. To do so, slice your data into different periods. Rerun the notebook with the updated parameters, and record the results in your `README.md` file. Answer the following question: What impact resulted from increasing or decreasing the training window?
#
# > **Hint** To adjust the size of the training dataset, you can use a different `DateOffset` value&mdash;for example, six months. Be aware that changing the size of the training dataset also affects the size of the testing dataset.
#
# 2. Tune the trading algorithm by adjusting the SMA input features. Adjust one or both of the windows for the algorithm. Rerun the notebook with the updated parameters, and record the results in your `README.md` file. Answer the following question: What impact resulted from increasing or decreasing either or both of the SMA windows?
#
# 3. Choose the set of parameters that best improved the trading algorithm returns. Save a PNG image of the cumulative product of the actual returns vs. the strategy returns, and document your conclusion in your `README.md` file.
#
# #### Evaluate a New Machine Learning Classifier
#
# In this section, you’ll use the original parameters that the starter code provided. But, you’ll apply them to the performance of a second machine learning model. To do so, complete the following steps:
#
# 1. Import a new classifier, such as `AdaBoost`, `DecisionTreeClassifier`, or `LogisticRegression`. (For the full list of classifiers, refer to the [Supervised learning page](https://scikit-learn.org/stable/supervised_learning.html) in the scikit-learn documentation.)
#
# 2. Using the original training data as the baseline model, fit another model with the new classifier.
#
# 3. Backtest the new model to evaluate its performance. Save a PNG image of the cumulative product of the actual returns vs. the strategy returns for this updated trading algorithm, and write your conclusions in your `README.md` file. Answer the following questions: Did this new model perform better or worse than the provided baseline model? Did this new model perform better or worse than your tuned trading algorithm?
#
# #### Create an Evaluation Report
#
# In the previous sections, you updated your `README.md` file with your conclusions. To accomplish this section, you need to add a summary evaluation report at the end of the `README.md` file. For this report, express your final conclusions and analysis. Support your findings by using the PNG images that you created.

# %%
# Imports
import pandas as pd
import numpy as np
from pathlib import Path
import hvplot.pandas
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.preprocessing import StandardScaler
from pandas.tseries.offsets import DateOffset
from sklearn.metrics import classification_report

# %% [markdown]
# ---
#
# ## Establish a Baseline Performance
#
# In this section, you’ll run the provided starter code to establish a baseline performance for the trading algorithm. To do so, complete the following steps.
#
# Open the Jupyter notebook. Restart the kernel, run the provided cells that correspond with the first three steps, and then proceed to step four.

# %% [markdown]
# ### Step 1: Import the OHLCV dataset into a Pandas DataFrame.

# %%
# Import the OHLCV dataset into a Pandas Dataframe
ohlcv_df = pd.read_csv(
    Path("./Resources/emerging_markets_ohlcv.csv"), 
    index_col='date', 
    infer_datetime_format=True, 
    parse_dates=True
)

# Review the DataFrame
ohlcv_df.head()
# Out:
# C:\Users\jan\AppData\Local\Temp\ipykernel_33772\566489611.py:2: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   ohlcv_df = pd.read_csv(
# C:\Users\jan\AppData\Local\Temp\ipykernel_33772\566489611.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ohlcv_df = pd.read_csv(
#                       open   high    low  close  volume
# date
# 2015-01-21 09:30:00  23.83  23.83  23.83  23.83     100
# 2015-01-21 11:00:00  23.98  23.98  23.98  23.98     100
# 2015-01-22 15:00:00  24.42  24.42  24.42  24.42     100
# 2015-01-22 15:15:00  24.42  24.44  24.42  24.44     200
# 2015-01-22 15:30:00  24.46  24.46  24.46  24.46     200

# %%
# Filter the date index and close columns
signals_df = ohlcv_df.loc[:, ["close"]]

# Use the pct_change function to generate returns from close prices
signals_df["Actual Returns"] = signals_df["close"].pct_change()

# Drop all NaN values from the DataFrame
signals_df = signals_df.dropna()

# Review the DataFrame
display(signals_df.head())
display(signals_df.tail())
# Out:
#                      close  Actual Returns
# date
# 2015-01-21 11:00:00  23.98        0.006295
# 2015-01-22 15:00:00  24.42        0.018349
# 2015-01-22 15:15:00  24.44        0.000819
# 2015-01-22 15:30:00  24.46        0.000818
# 2015-01-26 12:30:00  24.33       -0.005315
#                      close  Actual Returns
# date
# 2021-01-22 09:30:00  33.27       -0.006866
# 2021-01-22 11:30:00  33.35        0.002405
# 2021-01-22 13:45:00  33.42        0.002099
# 2021-01-22 14:30:00  33.47        0.001496
# 2021-01-22 15:45:00  33.44       -0.000896

# %% [markdown]
# ## Step 2: Generate trading signals using short- and long-window SMA values.

# %%
# Set the short window and long window
short_window = 4
long_window = 100

# Generate the fast and slow simple moving averages (4 and 100 days, respectively)
signals_df['SMA_Fast'] = signals_df['close'].rolling(window=short_window).mean()
signals_df['SMA_Slow'] = signals_df['close'].rolling(window=long_window).mean()

signals_df = signals_df.dropna()

# Review the DataFrame
display(signals_df.head())
display(signals_df.tail())
# Out:
#                      close  Actual Returns  SMA_Fast  SMA_Slow
# date
# 2015-04-02 14:45:00  24.92        0.000000   24.9175   24.3214
# 2015-04-02 15:00:00  24.92        0.000000   24.9200   24.3308
# 2015-04-02 15:15:00  24.94        0.000803   24.9250   24.3360
# 2015-04-02 15:30:00  24.95        0.000401   24.9325   24.3411
# 2015-04-02 15:45:00  24.98        0.001202   24.9475   24.3463
#                      close  Actual Returns  SMA_Fast  SMA_Slow
# date
# 2021-01-22 09:30:00  33.27       -0.006866   33.2025  30.40215
# 2021-01-22 11:30:00  33.35        0.002405   33.2725  30.44445
# 2021-01-22 13:45:00  33.42        0.002099   33.3850  30.48745
# 2021-01-22 14:30:00  33.47        0.001496   33.3775  30.53085
# 2021-01-22 15:45:00  33.44       -0.000896   33.4200  30.57495

# %%
# Initialize the new Signal column
signals_df['Signal'] = 0.0

# When Actual Returns are greater than or equal to 0, generate signal to buy stock long
signals_df.loc[(signals_df['Actual Returns'] >= 0), 'Signal'] = 1

# When Actual Returns are less than 0, generate signal to sell stock short
signals_df.loc[(signals_df['Actual Returns'] < 0), 'Signal'] = -1

# Review the DataFrame
display(signals_df.head())
display(signals_df.tail())
# Out:
#                      close  Actual Returns  SMA_Fast  SMA_Slow  Signal
# date
# 2015-04-02 14:45:00  24.92        0.000000   24.9175   24.3214     1.0
# 2015-04-02 15:00:00  24.92        0.000000   24.9200   24.3308     1.0
# 2015-04-02 15:15:00  24.94        0.000803   24.9250   24.3360     1.0
# 2015-04-02 15:30:00  24.95        0.000401   24.9325   24.3411     1.0
# 2015-04-02 15:45:00  24.98        0.001202   24.9475   24.3463     1.0
#                      close  Actual Returns  SMA_Fast  SMA_Slow  Signal
# date
# 2021-01-22 09:30:00  33.27       -0.006866   33.2025  30.40215    -1.0
# 2021-01-22 11:30:00  33.35        0.002405   33.2725  30.44445     1.0
# 2021-01-22 13:45:00  33.42        0.002099   33.3850  30.48745     1.0
# 2021-01-22 14:30:00  33.47        0.001496   33.3775  30.53085     1.0
# 2021-01-22 15:45:00  33.44       -0.000896   33.4200  30.57495    -1.0

# %%
signals_df['Signal'].value_counts()
# Out:
# Signal
#  1.0    2368
# -1.0    1855
# Name: count, dtype: int64

# %%
# Calculate the strategy returns and add them to the signals_df DataFrame
signals_df['Strategy Returns'] = signals_df['Actual Returns'] * signals_df['Signal'].shift()

# Review the DataFrame
display(signals_df.head())
display(signals_df.tail())
# Out:
#                      close  Actual Returns  SMA_Fast  SMA_Slow  Signal  \
# date
# 2015-04-02 14:45:00  24.92        0.000000   24.9175   24.3214     1.0
# 2015-04-02 15:00:00  24.92        0.000000   24.9200   24.3308     1.0
# 2015-04-02 15:15:00  24.94        0.000803   24.9250   24.3360     1.0
# 2015-04-02 15:30:00  24.95        0.000401   24.9325   24.3411     1.0
# 2015-04-02 15:45:00  24.98        0.001202   24.9475   24.3463     1.0
#
#                      Strategy Returns
# date
# 2015-04-02 14:45:00               NaN
# 2015-04-02 15:00:00          0.000000
# 2015-04-02 15:15:00          0.000803
# 2015-04-02 15:30:00          0.000401
# 2015-04-02 15:45:00          0.001202
#                      close  Actual Returns  SMA_Fast  SMA_Slow  Signal  \
# date
# 2021-01-22 09:30:00  33.27       -0.006866   33.2025  30.40215    -1.0
# 2021-01-22 11:30:00  33.35        0.002405   33.2725  30.44445     1.0
# 2021-01-22 13:45:00  33.42        0.002099   33.3850  30.48745     1.0
# 2021-01-22 14:30:00  33.47        0.001496   33.3775  30.53085     1.0
# 2021-01-22 15:45:00  33.44       -0.000896   33.4200  30.57495    -1.0
#
#                      Strategy Returns
# date
# 2021-01-22 09:30:00         -0.006866
# 2021-01-22 11:30:00         -0.002405
# 2021-01-22 13:45:00          0.002099
# 2021-01-22 14:30:00          0.001496
# 2021-01-22 15:45:00         -0.000896

# %%
# Plot Strategy Returns to examine performance
(1 + signals_df['Strategy Returns']).cumprod().plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ### Step 3: Split the data into training and testing datasets.

# %%
# Assign a copy of the sma_fast and sma_slow columns to a features DataFrame called X
X = signals_df[['SMA_Fast', 'SMA_Slow']].shift().dropna()

# Review the DataFrame
X.head()
# Out:
#                      SMA_Fast  SMA_Slow
# date
# 2015-04-02 15:00:00   24.9175   24.3214
# 2015-04-02 15:15:00   24.9200   24.3308
# 2015-04-02 15:30:00   24.9250   24.3360
# 2015-04-02 15:45:00   24.9325   24.3411
# 2015-04-06 09:30:00   24.9475   24.3463

# %%
# Create the target set selecting the Signal column and assiging it to y
y = signals_df['Signal']

# Review the value counts
y.value_counts()
# Out:
# Signal
#  1.0    2368
# -1.0    1855
# Name: count, dtype: int64

# %%
# Select the start of the training period
training_begin = X.index.min()

# Display the training begin date
print(training_begin)
# Out:
# 2015-04-02 15:00:00

# %%
# Select the ending period for the training data with an offset of 3 months
training_end = X.index.min() + DateOffset(months=3)

# Display the training end date
print(training_end)
# Out:
# 2015-07-02 15:00:00

# %%
# Generate the X_train and y_train DataFrames
X_train = X.loc[training_begin:training_end]
y_train = y.loc[training_begin:training_end]

# Review the X_train DataFrame
X_train.head()
# Out:
#                      SMA_Fast  SMA_Slow
# date
# 2015-04-02 15:00:00   24.9175   24.3214
# 2015-04-02 15:15:00   24.9200   24.3308
# 2015-04-02 15:30:00   24.9250   24.3360
# 2015-04-02 15:45:00   24.9325   24.3411
# 2015-04-06 09:30:00   24.9475   24.3463

# %%
# Generate the X_test and y_test DataFrames
X_test = X.loc[training_end+DateOffset(hours=1):]
y_test = y.loc[training_end+DateOffset(hours=1):]

# Review the X_test DataFrame
X_train.head()
# Out:
#                      SMA_Fast  SMA_Slow
# date
# 2015-04-02 15:00:00   24.9175   24.3214
# 2015-04-02 15:15:00   24.9200   24.3308
# 2015-04-02 15:30:00   24.9250   24.3360
# 2015-04-02 15:45:00   24.9325   24.3411
# 2015-04-06 09:30:00   24.9475   24.3463

# %%
# Scale the features DataFrames

# Create a StandardScaler instance
scaler = StandardScaler()

# Apply the scaler model to fit the X-train data
X_scaler = scaler.fit(X_train)

# Transform the X_train and X_test DataFrames using the X_scaler
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### Step 4: Use the `SVC` classifier model from SKLearn's support vector machine (SVM) learning method to fit the training data and make predictions based on the testing data. Review the predictions.

# %%
from sklearn.svm import SVC

# From SVM, instantiate SVC classifier model instance
svm_model = SVC()
 
# Fit the model to the data using the training data
svm_model.fit(X_train_scaled, y_train)
 
# Use the testing data to make the model predictions
svm_pred = svm_model.predict(X_test_scaled)

# Review the model's predicted values
print(svm_pred)
# Out:
# [1. 1. 1. ... 1. 1. 1.]

# %% [markdown]
# ### Step 5: Review the classification report associated with the `SVC` model predictions.

# %%
from sklearn.metrics import classification_report

# Use a classification report to evaluate the model using the predictions and testing data
svm_testing_report = classification_report(y_test, svm_pred)

# Print the classification report
print(svm_testing_report)
# Out:
#               precision    recall  f1-score   support
#
#         -1.0       0.43      0.04      0.07      1804
#          1.0       0.56      0.96      0.71      2288
#
#     accuracy                           0.55      4092
#    macro avg       0.49      0.50      0.39      4092
# weighted avg       0.50      0.55      0.43      4092

# %% [markdown]
# ### Step 6: Create a predictions DataFrame that contains columns for “Predicted” values, “Actual Returns”, and “Strategy Returns”.

# %%
# Create a new empty predictions DataFrame:

# Create a predictions DataFrame
predictions_df = pd.DataFrame(index=y_test.index)

# Add the SVM model predictions to the DataFrame
predictions_df['Predicted'] = svm_pred

# Add the actual returns to the DataFrame
predictions_df['Actual Returns'] = signals_df.loc[predictions_df.index, 'Actual Returns']

# Add the strategy returns to the DataFrame
predictions_df['Strategy Returns'] = predictions_df['Actual Returns'] * predictions_df['Predicted'].shift()

# Review the DataFrame
display(predictions_df)
# Out:
#                      Predicted  Actual Returns  Strategy Returns
# date
# 2015-07-06 10:00:00        1.0       -0.025715               NaN
# 2015-07-06 10:45:00        1.0        0.007237          0.007237
# 2015-07-06 14:15:00        1.0       -0.009721         -0.009721
# 2015-07-06 14:30:00        1.0       -0.003841         -0.003841
# 2015-07-07 11:30:00        1.0       -0.018423         -0.018423
# ...                        ...             ...               ...
# 2021-01-22 09:30:00        1.0       -0.006866         -0.006866
# 2021-01-22 11:30:00        1.0        0.002405          0.002405
# 2021-01-22 13:45:00        1.0        0.002099          0.002099
# 2021-01-22 14:30:00        1.0        0.001496          0.001496
# 2021-01-22 15:45:00        1.0       -0.000896         -0.000896
#
# [4092 rows x 3 columns]

# %% [markdown]
# ### Step 7: Create a cumulative return plot that shows the actual returns vs. the strategy returns. Save a PNG image of this plot. This will serve as a baseline against which to compare the effects of tuning the trading algorithm.

# %%
# Manual Short & long Window Title Additions
# short_window = 30
# long_window = 90

# Plot the actual returns versus the strategy returns
plt.figure(figsize=(10,6))
plt.plot((1 + predictions_df['Actual Returns']).cumprod(), label='Actual Returns')
plt.plot((1 + predictions_df['Strategy Returns']).cumprod(), label='Strategy Returns')
plt.legend()
plt.title("Actual Returns vs. Strategy Returns\nShort Window: {} | Long Window: {}".format(short_window, long_window))
plt.xlabel("Date")
plt.ylabel("Cumulative Returns")
plt.tight_layout()

# Use the short_window and long_window values in the filename
filename = "cumulative_returns_short{}_long{}.png".format(short_window, long_window)

# Save the plot as a PNG file using the dynamic filename
plt.savefig(filename)

plt.show()

# %% [markdown]
# ---
#
# ## Tune the Baseline Trading Algorithm

# %% [markdown]
# In this section, you’ll tune, or adjust, the model’s input features to find the parameters that result in the best trading outcomes. You’ll choose the best by comparing the cumulative products of the strategy returns.

# %% [markdown]
# ### Step 1: Tune the training algorithm by adjusting the size of the training dataset.
#
# To do so, slice your data into different periods. Rerun the notebook with the updated parameters, and record the results in your `README.md` file.
#
# Answer the following question: What impact resulted from increasing or decreasing the training window?

# %% [markdown]
# ### Step 2: Tune the trading algorithm by adjusting the SMA input features.
#
# Adjust one or both of the windows for the algorithm. Rerun the notebook with the updated parameters, and record the results in your `README.md` file.
#
# Answer the following question: What impact resulted from increasing or decreasing either or both of the SMA windows?

# %% [markdown]
# ### Step 3: Choose the set of parameters that best improved the trading algorithm returns.
#
# Save a PNG image of the cumulative product of the actual returns vs. the strategy returns, and document your conclusion in your `README.md` file.

# %% [markdown]
# ---
#
# ## Evaluate a New Machine Learning Classifier
#
# In this section, you’ll use the original parameters that the starter code provided. But, you’ll apply them to the performance of a second machine learning model.

# %% [markdown]
# ### Step 1:  Import a new classifier, such as `AdaBoost`, `DecisionTreeClassifier`, or `LogisticRegression`. (For the full list of classifiers, refer to the [Supervised learning page](https://scikit-learn.org/stable/supervised_learning.html) in the scikit-learn documentation.)

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# Import a new classifier from SKLearn
new_model = AdaBoostClassifier()

# Initiate the model instance
new_model = DecisionTreeClassifier()

# %% [markdown]
# ### Step 2: Using the original training data as the baseline model, fit another model with the new classifier.

# %%
# Fit the model using the training data
new_model.fit(X_train_scaled, y_train)

# Use the testing dataset to generate the predictions for the new model
new_pred = new_model.predict(X_test_scaled)

# Review the model's predicted values
print(new_pred)
# Out:
# [ 1. -1. -1. ... -1. -1. -1.]

# %% [markdown]
# ### Step 3: Backtest the new model to evaluate its performance.
#
# Save a PNG image of the cumulative product of the actual returns vs. the strategy returns for this updated trading algorithm, and write your conclusions in your `README.md` file.
#
# Answer the following questions:
# Did this new model perform better or worse than the provided baseline model?
# Did this new model perform better or worse than your tuned trading algorithm?

# %%
# Use a classification report to evaluate the model using the predictions and testing data
new_model_report = classification_report(y_test, new_pred)

# Print the classification report
print("New Model Classification Report:")
print(new_model_report)
# Out:
# New Model Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.44      0.83      0.57      1804
#          1.0       0.53      0.15      0.23      2288
#
#     accuracy                           0.45      4092
#    macro avg       0.49      0.49      0.40      4092
# weighted avg       0.49      0.45      0.38      4092

# %%
# Create a new empty predictions DataFrame
new_predictions_df = pd.DataFrame(index=X_test.index)

# Add the SVM model predictions to the DataFrame
new_predictions_df['Predicted'] = new_pred

# Add the actual returns to the DataFrame
# Ensure you're referencing the correct DataFrame that includes 'Actual Returns'
new_predictions_df['Actual Returns'] = signals_df.loc[X_test.index, 'Actual Returns']

# Add the strategy returns to the DataFrame
new_predictions_df['Strategy Returns'] = new_predictions_df['Predicted'].shift(1) * new_predictions_df['Actual Returns']

# Review the DataFrame
print(new_predictions_df)
# Out:
#                      Predicted  Actual Returns  Strategy Returns
# date
# 2015-07-06 10:00:00        1.0       -0.025715               NaN
# 2015-07-06 10:45:00       -1.0        0.007237          0.007237
# 2015-07-06 14:15:00       -1.0       -0.009721          0.009721
# 2015-07-06 14:30:00       -1.0       -0.003841          0.003841
# 2015-07-07 11:30:00       -1.0       -0.018423          0.018423
# ...                        ...             ...               ...
# 2021-01-22 09:30:00       -1.0       -0.006866          0.006866
# 2021-01-22 11:30:00       -1.0        0.002405         -0.002405
# 2021-01-22 13:45:00       -1.0        0.002099         -0.002099
# 2021-01-22 14:30:00       -1.0        0.001496         -0.001496
# 2021-01-22 15:45:00       -1.0       -0.000896          0.000896
#
# [4092 rows x 3 columns]

# %%
# Plot the actual returns versus the strategy returns for the new model
plt.figure(figsize=(10,6))
# Explicitly define the plotting range to match the new_predictions_df's date range
plt.plot((1 + new_predictions_df['Actual Returns'][new_predictions_df.index.min():new_predictions_df.index.max()]).cumprod(), label='Actual Returns', color='blue')
plt.plot((1 + new_predictions_df['Strategy Returns'][new_predictions_df.index.min():new_predictions_df.index.max()]).cumprod(), label='Strategy Returns', color='orange')
plt.legend()
plt.title(f"Actual Returns vs. Strategy Returns - New Model\nShort Window: {short_window} | Long Window: {long_window}")
plt.xlabel("Date")
plt.ylabel("Cumulative Returns")
plt.xticks(rotation=45)
plt.tight_layout()

# Dynamically name the file to include short_window and long_window values
filename = f"new_model_strategy_returns_short{short_window}_long{long_window}.png"
plt.savefig(filename)
plt.show()

# %% [markdown]
# ---
#
# ## 1000 Tests - Strategic Exploration of SMA Windows with SVC Analysis
#
# This comprehensive script embarks on a rigorous exploration of trading strategies derived from the Simple Moving Averages (SMA) concept, refined through Support Vector Classifier (SVC) analysis. Targeting the emerging markets, the script conducts a thousand iterations, each examining a unique pair of short and long SMA windows. It leverages the SVC model to generate trading signals, aiming to identify configurations that maximize predictive accuracy. The process meticulously calculates the actual versus strategy returns for each iteration, consolidating these insights into a results DataFrame. This DataFrame is subsequently sorted based on accuracy, facilitating a clear visualization of the most effective strategies. The endeavor culminates in the creation of a detailed report, encapsulated in a CSV file, which serves as a valuable resource for enhancing trading strategies in the complex dynamics of emerging markets.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
import random
import os
import warnings

with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=FutureWarning)
    results_df = pd.concat([results_df, new_row], ignore_index=True)

# Ensure correct parsing of the date format
df_original = pd.read_csv('Resources/emerging_markets_ohlcv.csv')
df_original['date'] = pd.to_datetime(df_original['date'], format='%m/%d/%y %H:%M')
df_original.set_index('date', inplace=True)

training_window_start = '2019-01-01'
training_window_end = '2020-01-01'

# Initialize a DataFrame to store the results
results_df = pd.DataFrame(columns=['Short Window', 'Long Window', 'Accuracy'])

for i in range(1000):
    short_window = random.randint(3, 138)
    long_window = random.randint(short_window + 1, 140)
    print(f"Trying window settings: short={short_window}, long={long_window}.")

    df = df_original.copy()
    df['short_mavg'] = df['close'].rolling(window=short_window, min_periods=1).mean()
    df['long_mavg'] = df['close'].rolling(window=long_window, min_periods=1).mean()
    df['signal'] = np.where(df['short_mavg'] > df['long_mavg'], 1, -1)
    df['actual_returns'] = df['close'].pct_change()
    df.dropna(inplace=True)

    if df.empty:
        print(f"Empty dataset for window settings: short={short_window}, long={long_window}. Skipping.")
        continue

    X = df[['short_mavg', 'long_mavg']]
    y = df['signal']
    X_train = X.loc[training_window_start:training_window_end]
    y_train = y.loc[training_window_start:training_window_end]
    X_test = X.loc[training_window_end:]
    y_test = y.loc[training_window_end:]

    if X_train.empty or X_test.empty:
        print("Empty training or testing set. Skipping.")
        continue

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    model = SVC()
    model.fit(X_train_scaled, y_train)
    predictions = model.predict(X_test_scaled)
    accuracy = accuracy_score(y_test, predictions)

    df.loc[X_test.index, 'predicted_signal'] = predictions
    df['strategy_returns'] = df['actual_returns'] * df['predicted_signal'].shift()

    # Append results to DataFrame using pd.concat
    new_row = pd.DataFrame({'Short Window': [short_window], 'Long Window': [long_window], 'Accuracy': [accuracy]})
    results_df = pd.concat([results_df, new_row], ignore_index=True)

# Sort the DataFrame by 'Accuracy' in descending order
sorted_results_df = results_df.sort_values(by='Accuracy', ascending=False)

# Export the sorted DataFrame to a CSV file
sorted_results_df.to_csv('strategy_results_svc_long_list.csv', index=False)
print("Results summary saved to strategy_results_svc_long_list.cs")
# Out:
# Trying window settings: short=61, long=74.
# Trying window settings: short=44, long=106.
# Trying window settings: short=131, long=136.
# Trying window settings: short=129, long=135.
# Trying window settings: short=25, long=52.
# Trying window settings: short=4, long=87.
# Trying window settings: short=112, long=120.
# Trying window settings: short=68, long=108.
# C:\Users\jan\AppData\Local\Temp\ipykernel_13836\334495846.py:67: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, new_row], ignore_index=True)
# Trying window settings: short=4, long=82.
# Trying window settings: short=28, long=88.
# Trying window settings: short=70, long=86.
# Trying window settings: short=58, long=125.
# Trying window settings: short=50, long=100.
# Trying window settings: short=65, long=101.
# Trying window settings: short=22, long=40.
# Trying window settings: short=97, long=139.
# Trying window settings: short=64, long=114.
# Trying window settings: short=11, long=26.
# Trying window settings: short=49, long=97.
# Trying window settings: short=25, long=57.
# Trying window settings: short=97, long=101.
# Trying window settings: short=9, long=113.
# Trying window settings: short=28, long=35.
# Trying window settings: short=37, long=139.
# Trying window settings: short=71, long=97.
# Trying window settings: short=123, long=125.
# Trying window settings: short=85, long=118.
# Trying window settings: short=113, long=130.
# Trying window settings: short=111, long=139.
# Trying window settings: short=9, long=80.
# Trying window settings: short=73, long=124.
# Trying window settings: short=87, long=105.
# Trying window settings: short=128, long=135.
# Trying window settings: short=24, long=29.
# Trying window settings: short=18, long=116.
# Trying window settings: short=10, long=13.
# Trying window settings: short=124, long=128.
# Trying window settings: short=3, long=64.
# Trying window settings: short=100, long=119.
# Trying window settings: short=81, long=122.
# Trying window settings: short=104, long=130.
# Trying window settings: short=76, long=100.
# Trying window settings: short=100, long=134.
# Trying window settings: short=114, long=129.
# Trying window settings: short=107, long=111.
# Trying window settings: short=14, long=22.
# Trying window settings: short=63, long=129.
# Trying window settings: short=112, long=125.
# Trying window settings: short=82, long=86.
# Trying window settings: short=85, long=139.
# Trying window settings: short=28, long=93.
# Trying window settings: short=28, long=113.
# Trying window settings: short=4, long=133.
# Trying window settings: short=30, long=124.
# Trying window settings: short=8, long=30.
# Trying window settings: short=130, long=138.
# Trying window settings: short=115, long=129.
# Trying window settings: short=94, long=137.
# Trying window settings: short=135, long=139.
# Trying window settings: short=136, long=139.
# Trying window settings: short=48, long=116.
# Trying window settings: short=86, long=118.
# Trying window settings: short=134, long=136.
# Trying window settings: short=47, long=92.
# Trying window settings: short=68, long=114.
# Trying window settings: short=9, long=130.
# Trying window settings: short=123, long=135.
# Trying window settings: short=58, long=63.
# Trying window settings: short=134, long=138.
# Trying window settings: short=121, long=127.
# Trying window settings: short=125, long=129.
# Trying window settings: short=64, long=67.
# Trying window settings: short=116, long=131.
# Trying window settings: short=115, long=131.
# Trying window settings: short=70, long=136.
# Trying window settings: short=42, long=57.
# Trying window settings: short=54, long=95.
# Trying window settings: short=65, long=120.
# Trying window settings: short=119, long=121.
# Trying window settings: short=74, long=131.
# Trying window settings: short=36, long=121.
# Trying window settings: short=105, long=134.
# Trying window settings: short=68, long=133.
# Trying window settings: short=130, long=135.
# Trying window settings: short=16, long=23.
# Trying window settings: short=57, long=114.
# Trying window settings: short=133, long=139.
# Trying window settings: short=38, long=78.
# Trying window settings: short=127, long=128.
# Trying window settings: short=86, long=132.
# Trying window settings: short=29, long=43.
# Trying window settings: short=42, long=139.
# Trying window settings: short=70, long=126.
# Trying window settings: short=14, long=98.
# Trying window settings: short=88, long=139.
# Trying window settings: short=59, long=83.
# Trying window settings: short=23, long=71.
# Trying window settings: short=36, long=95.
# Trying window settings: short=46, long=115.
# Trying window settings: short=75, long=109.
# Trying window settings: short=96, long=116.
# Trying window settings: short=58, long=85.
# Trying window settings: short=7, long=88.
# Trying window settings: short=59, long=120.
# Trying window settings: short=136, long=140.
# Trying window settings: short=5, long=7.
# Trying window settings: short=115, long=135.
# Trying window settings: short=134, long=135.
# Trying window settings: short=42, long=75.
# Trying window settings: short=67, long=123.
# Trying window settings: short=17, long=31.
# Trying window settings: short=136, long=140.
# Trying window settings: short=14, long=61.
# Trying window settings: short=136, long=137.
# Trying window settings: short=32, long=62.
# Trying window settings: short=89, long=130.
# Trying window settings: short=21, long=37.
# Trying window settings: short=57, long=73.
# Trying window settings: short=77, long=78.
# Trying window settings: short=33, long=57.
# Trying window settings: short=123, long=132.
# Trying window settings: short=40, long=59.
# Trying window settings: short=52, long=115.
# Trying window settings: short=18, long=57.
# Trying window settings: short=43, long=58.
# Trying window settings: short=132, long=134.
# Trying window settings: short=136, long=140.
# Trying window settings: short=87, long=94.
# Trying window settings: short=111, long=120.
# Trying window settings: short=69, long=129.
# Trying window settings: short=114, long=117.
# Trying window settings: short=18, long=60.
# Trying window settings: short=99, long=100.
# Trying window settings: short=8, long=57.
# Trying window settings: short=129, long=134.
# Trying window settings: short=100, long=108.
# Trying window settings: short=92, long=99.
# Trying window settings: short=29, long=30.
# Trying window settings: short=68, long=138.
# Trying window settings: short=77, long=102.
# Trying window settings: short=13, long=84.
# Trying window settings: short=61, long=120.
# Trying window settings: short=53, long=67.
# Trying window settings: short=114, long=122.
# Trying window settings: short=95, long=105.
# Trying window settings: short=14, long=63.
# Trying window settings: short=76, long=133.
# Trying window settings: short=97, long=136.
# Trying window settings: short=133, long=136.
# Trying window settings: short=15, long=49.
# Trying window settings: short=38, long=106.
# Trying window settings: short=56, long=94.
# Trying window settings: short=93, long=126.
# Trying window settings: short=18, long=30.
# Trying window settings: short=12, long=22.
# Trying window settings: short=56, long=74.
# Trying window settings: short=52, long=114.
# Trying window settings: short=33, long=140.
# Trying window settings: short=78, long=81.
# Trying window settings: short=79, long=133.
# Trying window settings: short=102, long=126.
# Trying window settings: short=31, long=111.
# Trying window settings: short=26, long=52.
# Trying window settings: short=42, long=107.
# Trying window settings: short=61, long=133.
# Trying window settings: short=51, long=116.
# Trying window settings: short=51, long=69.
# Trying window settings: short=28, long=86.
# Trying window settings: short=42, long=62.
# Trying window settings: short=15, long=47.
# Trying window settings: short=53, long=110.
# Trying window settings: short=96, long=119.
# Trying window settings: short=73, long=77.
# Trying window settings: short=79, long=96.
# Trying window settings: short=42, long=69.
# Trying window settings: short=10, long=27.
# Trying window settings: short=109, long=136.
# Trying window settings: short=49, long=58.
# Trying window settings: short=11, long=47.
# Trying window settings: short=37, long=139.
# Trying window settings: short=20, long=56.
# Trying window settings: short=127, long=140.
# Trying window settings: short=84, long=100.
# Trying window settings: short=10, long=26.
# Trying window settings: short=34, long=42.
# Trying window settings: short=49, long=94.
# Trying window settings: short=134, long=138.
# Trying window settings: short=95, long=102.
# Trying window settings: short=72, long=120.
# Trying window settings: short=67, long=124.
# Trying window settings: short=98, long=106.
# Trying window settings: short=80, long=84.
# Trying window settings: short=90, long=100.
# Trying window settings: short=52, long=105.
# Trying window settings: short=65, long=107.
# Trying window settings: short=18, long=57.
# Trying window settings: short=137, long=138.
# Trying window settings: short=52, long=121.
# Trying window settings: short=67, long=101.
# Trying window settings: short=43, long=127.
# Trying window settings: short=15, long=102.
# Trying window settings: short=106, long=115.
# Trying window settings: short=132, long=140.
# Trying window settings: short=47, long=100.
# Trying window settings: short=116, long=137.
# Trying window settings: short=3, long=135.
# Trying window settings: short=38, long=134.
# Trying window settings: short=101, long=102.
# Trying window settings: short=107, long=120.
# Trying window settings: short=52, long=84.
# Trying window settings: short=84, long=102.
# Trying window settings: short=117, long=137.
# Trying window settings: short=115, long=134.
# Trying window settings: short=128, long=130.
# Trying window settings: short=59, long=100.
# Trying window settings: short=21, long=134.
# Trying window settings: short=102, long=128.
# Trying window settings: short=93, long=120.
# Trying window settings: short=111, long=125.
# Trying window settings: short=11, long=40.
# Trying window settings: short=23, long=94.
# Trying window settings: short=104, long=114.
# Trying window settings: short=9, long=122.
# Trying window settings: short=4, long=8.
# Trying window settings: short=129, long=137.
# Trying window settings: short=100, long=109.
# Trying window settings: short=122, long=132.
# Trying window settings: short=122, long=127.
# Trying window settings: short=31, long=96.
# Trying window settings: short=12, long=14.
# Trying window settings: short=116, long=119.
# Trying window settings: short=66, long=71.
# Trying window settings: short=109, long=134.
# Trying window settings: short=100, long=115.
# Trying window settings: short=31, long=125.
# Trying window settings: short=72, long=85.
# Trying window settings: short=32, long=38.
# Trying window settings: short=120, long=123.
# Trying window settings: short=60, long=114.
# Trying window settings: short=94, long=129.
# Trying window settings: short=67, long=107.
# Trying window settings: short=75, long=129.
# Trying window settings: short=133, long=137.
# Trying window settings: short=33, long=108.
# Trying window settings: short=112, long=125.
# Trying window settings: short=5, long=101.
# Trying window settings: short=80, long=99.
# Trying window settings: short=29, long=140.
# Trying window settings: short=63, long=71.
# Trying window settings: short=69, long=94.
# Trying window settings: short=86, long=131.
# Trying window settings: short=6, long=57.
# Trying window settings: short=46, long=57.
# Trying window settings: short=127, long=137.
# Trying window settings: short=48, long=84.
# Trying window settings: short=47, long=128.
# Trying window settings: short=103, long=112.
# Trying window settings: short=132, long=139.
# Trying window settings: short=43, long=125.
# Trying window settings: short=63, long=77.
# Trying window settings: short=127, long=133.
# Trying window settings: short=129, long=132.
# Trying window settings: short=20, long=99.
# Trying window settings: short=95, long=97.
# Trying window settings: short=16, long=20.
# Trying window settings: short=85, long=126.
# Trying window settings: short=7, long=96.
# Trying window settings: short=32, long=58.
# Trying window settings: short=66, long=118.
# Trying window settings: short=18, long=126.
# Trying window settings: short=36, long=63.
# Trying window settings: short=86, long=94.
# Trying window settings: short=137, long=138.
# Trying window settings: short=81, long=84.
# Trying window settings: short=12, long=84.
# Trying window settings: short=137, long=139.
# Trying window settings: short=131, long=135.
# Trying window settings: short=111, long=130.
# Trying window settings: short=65, long=135.
# Trying window settings: short=108, long=131.
# Trying window settings: short=7, long=117.
# Trying window settings: short=73, long=139.
# Trying window settings: short=107, long=113.
# Trying window settings: short=46, long=94.
# Trying window settings: short=87, long=111.
# Trying window settings: short=86, long=91.
# Trying window settings: short=77, long=113.
# Trying window settings: short=18, long=80.
# Trying window settings: short=87, long=99.
# Trying window settings: short=13, long=123.
# Trying window settings: short=109, long=134.
# Trying window settings: short=116, long=136.
# Trying window settings: short=39, long=111.
# Trying window settings: short=84, long=92.
# Trying window settings: short=93, long=136.
# Trying window settings: short=119, long=127.
# Trying window settings: short=109, long=117.
# Trying window settings: short=118, long=126.
# Trying window settings: short=40, long=128.
# Trying window settings: short=46, long=76.
# Trying window settings: short=55, long=136.
# Trying window settings: short=49, long=104.
# Trying window settings: short=100, long=140.
# Trying window settings: short=92, long=129.
# Trying window settings: short=119, long=122.
# Trying window settings: short=67, long=71.
# Trying window settings: short=97, long=98.
# Trying window settings: short=48, long=118.
# Trying window settings: short=28, long=90.
# Trying window settings: short=102, long=131.
# Trying window settings: short=46, long=81.
# Trying window settings: short=119, long=123.
# Trying window settings: short=124, long=133.
# Trying window settings: short=61, long=125.
# Trying window settings: short=65, long=127.
# Trying window settings: short=9, long=132.
# Trying window settings: short=129, long=132.
# Trying window settings: short=19, long=51.
# Trying window settings: short=105, long=111.
# Trying window settings: short=46, long=127.
# Trying window settings: short=82, long=123.
# Trying window settings: short=95, long=125.
# Trying window settings: short=121, long=137.
# Trying window settings: short=68, long=115.
# Trying window settings: short=90, long=125.
# Trying window settings: short=77, long=91.
# Trying window settings: short=122, long=129.
# Trying window settings: short=69, long=111.
# Trying window settings: short=75, long=125.
# Trying window settings: short=3, long=67.
# Trying window settings: short=54, long=131.
# Trying window settings: short=119, long=136.
# Trying window settings: short=63, long=101.
# Trying window settings: short=48, long=51.
# Trying window settings: short=123, long=135.
# Trying window settings: short=53, long=110.
# Trying window settings: short=133, long=134.
# Trying window settings: short=10, long=122.
# Trying window settings: short=99, long=138.
# Trying window settings: short=123, long=132.
# Trying window settings: short=15, long=16.
# Trying window settings: short=69, long=110.
# Trying window settings: short=31, long=83.
# Trying window settings: short=44, long=64.
# Trying window settings: short=92, long=132.
# Trying window settings: short=49, long=85.
# Trying window settings: short=75, long=127.
# Trying window settings: short=78, long=102.
# Trying window settings: short=44, long=118.
# Trying window settings: short=8, long=134.
# Trying window settings: short=21, long=28.
# Trying window settings: short=84, long=116.
# Trying window settings: short=22, long=53.
# Trying window settings: short=115, long=138.
# Trying window settings: short=124, long=130.
# Trying window settings: short=56, long=106.
# Trying window settings: short=14, long=131.
# Trying window settings: short=78, long=121.
# Trying window settings: short=46, long=78.
# Trying window settings: short=33, long=45.
# Trying window settings: short=125, long=138.
# Trying window settings: short=124, long=130.
# Trying window settings: short=28, long=120.
# Trying window settings: short=78, long=90.
# Trying window settings: short=118, long=126.
# Trying window settings: short=22, long=66.
# Trying window settings: short=43, long=77.
# Trying window settings: short=24, long=50.
# Trying window settings: short=49, long=133.
# Trying window settings: short=32, long=118.
# Trying window settings: short=119, long=129.
# Trying window settings: short=100, long=131.
# Trying window settings: short=110, long=122.
# Trying window settings: short=9, long=82.
# Trying window settings: short=117, long=123.
# Trying window settings: short=13, long=133.
# Trying window settings: short=101, long=135.
# Trying window settings: short=98, long=103.
# Trying window settings: short=14, long=48.
# Trying window settings: short=65, long=130.
# Trying window settings: short=62, long=127.
# Trying window settings: short=67, long=100.
# Trying window settings: short=101, long=118.
# Trying window settings: short=81, long=113.
# Trying window settings: short=122, long=137.
# Trying window settings: short=64, long=93.
# Trying window settings: short=17, long=43.
# Trying window settings: short=114, long=115.
# Trying window settings: short=138, long=140.
# Trying window settings: short=23, long=93.
# Trying window settings: short=58, long=135.
# Trying window settings: short=5, long=129.
# Trying window settings: short=17, long=98.
# Trying window settings: short=112, long=128.
# Trying window settings: short=101, long=103.
# Trying window settings: short=44, long=126.
# Trying window settings: short=14, long=94.
# Trying window settings: short=50, long=70.
# Trying window settings: short=40, long=73.
# Trying window settings: short=94, long=101.
# Trying window settings: short=135, long=140.
# Trying window settings: short=120, long=135.
# Trying window settings: short=39, long=64.
# Trying window settings: short=101, long=131.
# Trying window settings: short=46, long=79.
# Trying window settings: short=59, long=89.
# Trying window settings: short=68, long=121.
# Trying window settings: short=83, long=125.
# Trying window settings: short=79, long=81.
# Trying window settings: short=106, long=108.
# Trying window settings: short=60, long=88.
# Trying window settings: short=85, long=89.
# Trying window settings: short=129, long=140.
# Trying window settings: short=106, long=124.
# Trying window settings: short=3, long=23.
# Trying window settings: short=104, long=128.
# Trying window settings: short=20, long=102.
# Trying window settings: short=77, long=109.
# Trying window settings: short=107, long=124.
# Trying window settings: short=43, long=113.
# Trying window settings: short=76, long=82.
# Trying window settings: short=72, long=91.
# Trying window settings: short=125, long=140.
# Trying window settings: short=84, long=139.
# Trying window settings: short=100, long=106.
# Trying window settings: short=67, long=79.
# Trying window settings: short=3, long=138.
# Trying window settings: short=53, long=115.
# Trying window settings: short=117, long=120.
# Trying window settings: short=16, long=75.
# Trying window settings: short=40, long=79.
# Trying window settings: short=56, long=108.
# Trying window settings: short=93, long=122.
# Trying window settings: short=49, long=94.
# Trying window settings: short=113, long=122.
# Trying window settings: short=7, long=128.
# Trying window settings: short=126, long=134.
# Trying window settings: short=66, long=137.
# Trying window settings: short=107, long=129.
# Trying window settings: short=102, long=120.
# Trying window settings: short=13, long=24.
# Trying window settings: short=125, long=126.
# Trying window settings: short=98, long=131.
# Trying window settings: short=98, long=125.
# Trying window settings: short=138, long=140.
# Trying window settings: short=41, long=57.
# Trying window settings: short=77, long=85.
# Trying window settings: short=67, long=110.
# Trying window settings: short=59, long=139.
# Trying window settings: short=86, long=135.
# Trying window settings: short=25, long=105.
# Trying window settings: short=135, long=138.
# Trying window settings: short=36, long=101.
# Trying window settings: short=65, long=130.
# Trying window settings: short=67, long=110.
# Trying window settings: short=30, long=136.
# Trying window settings: short=97, long=110.
# Trying window settings: short=21, long=50.
# Trying window settings: short=129, long=137.
# Trying window settings: short=23, long=73.
# Trying window settings: short=137, long=139.
# Trying window settings: short=22, long=67.
# Trying window settings: short=35, long=105.
# Trying window settings: short=62, long=131.
# Trying window settings: short=91, long=134.
# Trying window settings: short=17, long=18.
# Trying window settings: short=79, long=105.
# Trying window settings: short=29, long=59.
# Trying window settings: short=71, long=77.
# Trying window settings: short=126, long=134.
# Trying window settings: short=8, long=95.
# Trying window settings: short=69, long=117.
# Trying window settings: short=62, long=93.
# Trying window settings: short=47, long=81.
# Trying window settings: short=40, long=80.
# Trying window settings: short=76, long=124.
# Trying window settings: short=5, long=14.
# Trying window settings: short=57, long=112.
# Trying window settings: short=17, long=126.
# Trying window settings: short=127, long=139.
# Trying window settings: short=3, long=12.
# Trying window settings: short=45, long=51.
# Trying window settings: short=123, long=135.
# Trying window settings: short=5, long=88.
# Trying window settings: short=92, long=129.
# Trying window settings: short=101, long=132.
# Trying window settings: short=35, long=127.
# Trying window settings: short=53, long=57.
# Trying window settings: short=19, long=24.
# Trying window settings: short=20, long=75.
# Trying window settings: short=104, long=119.
# Trying window settings: short=56, long=133.
# Trying window settings: short=95, long=101.
# Trying window settings: short=28, long=104.
# Trying window settings: short=85, long=110.
# Trying window settings: short=99, long=120.
# Trying window settings: short=43, long=129.
# Trying window settings: short=24, long=40.
# Trying window settings: short=9, long=89.
# Trying window settings: short=129, long=136.
# Trying window settings: short=111, long=112.
# Trying window settings: short=39, long=105.
# Trying window settings: short=84, long=93.
# Trying window settings: short=60, long=136.
# Trying window settings: short=63, long=129.
# Trying window settings: short=73, long=104.
# Trying window settings: short=66, long=119.
# Trying window settings: short=20, long=79.
# Trying window settings: short=79, long=83.
# Trying window settings: short=74, long=137.
# Trying window settings: short=85, long=131.
# Trying window settings: short=101, long=108.
# Trying window settings: short=127, long=131.
# Trying window settings: short=126, long=135.
# Trying window settings: short=24, long=41.
# Trying window settings: short=45, long=63.
# Trying window settings: short=84, long=140.
# Trying window settings: short=94, long=128.
# Trying window settings: short=95, long=131.
# Trying window settings: short=91, long=126.
# Trying window settings: short=103, long=116.
# Trying window settings: short=78, long=89.
# Trying window settings: short=63, long=125.
# Trying window settings: short=125, long=135.
# Trying window settings: short=108, long=123.
# Trying window settings: short=94, long=134.
# Trying window settings: short=106, long=121.
# Trying window settings: short=30, long=64.
# Trying window settings: short=58, long=100.
# Trying window settings: short=118, long=121.
# Trying window settings: short=74, long=95.
# Trying window settings: short=82, long=118.
# Trying window settings: short=110, long=127.
# Trying window settings: short=61, long=79.
# Trying window settings: short=54, long=55.
# Trying window settings: short=17, long=109.
# Trying window settings: short=42, long=134.
# Trying window settings: short=42, long=75.
# Trying window settings: short=42, long=83.
# Trying window settings: short=31, long=58.
# Trying window settings: short=125, long=131.
# Trying window settings: short=112, long=119.
# Trying window settings: short=74, long=93.
# Trying window settings: short=45, long=114.
# Trying window settings: short=105, long=117.
# Trying window settings: short=33, long=72.
# Trying window settings: short=93, long=125.
# Trying window settings: short=59, long=119.
# Trying window settings: short=133, long=139.
# Trying window settings: short=53, long=64.
# Trying window settings: short=46, long=57.
# Trying window settings: short=60, long=88.
# Trying window settings: short=90, long=96.
# Trying window settings: short=135, long=136.
# Trying window settings: short=105, long=107.
# Trying window settings: short=80, long=129.
# %% [markdown]
# ---
#
# ## Creating 20 Graphs - Enhanced SMA Trading Strategies with SVC Optimization
#
# This script delves into the optimization of Simple Moving Average (SMA) based trading strategies through the application of the Support Vector Classifier (SVC) model. By analyzing emerging market data, the script identifies the top 20 SMA window configurations based on accuracy from a pre-calculated dataset. It meticulously iterates through these configurations, applying SVC to predict trading signals based on short and long SMA windows. The effectiveness of each strategy is visually represented through cumulative return plots, highlighting the actual returns versus strategy returns. Accuracy metrics are finely tuned into the visualization, offering a clear comparison of each strategy's performance. This systematic approach aims to pinpoint the most promising SMA configurations, thereby enhancing trading decisions in the volatile environment of emerging markets.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import os

# Load your dataset
df_original = pd.read_csv('Resources/emerging_markets_ohlcv.csv')
df_original['date'] = pd.to_datetime(df_original['date'], format='%m/%d/%y %H:%M')
df_original.set_index('date', inplace=True)

# Load the strategy results and sort them by Accuracy in descending order
strategy_results = pd.read_csv('strategy_results_svc_long_list.csv')
top_strategy_results = strategy_results.sort_values(by='Accuracy', ascending=False).head(20)

training_window_start = '2019-01-01'
training_window_end = '2020-01-01'

# Ensure the Graphs folder exists
graphs_folder = 'Graphs'
if not os.path.exists(graphs_folder):
    os.makedirs(graphs_folder)

# Iterate over the top 20 strategy results
for index, row in top_strategy_results.iterrows():
    short_window = int(row['Short Window'])
    long_window = int(row['Long Window'])
    accuracy = row['Accuracy']  # Assuming the accuracy is stored in the CSV
    
    # Format the accuracy value
    accuracy_str = "{:.4f}".format(accuracy).replace('.', '')

    df = df_original.copy()
    df['short_mavg'] = df['close'].rolling(window=short_window, min_periods=1).mean()
    df['long_mavg'] = df['close'].rolling(window=long_window, min_periods=1).mean()
    df['signal'] = np.where(df['short_mavg'] > df['long_mavg'], 1, -1)
    df['actual_returns'] = df['close'].pct_change()
    df.dropna(inplace=True)

    X = df[['short_mavg', 'long_mavg']]
    y = df['signal']
    X_train = X.loc[training_window_start:training_window_end]
    y_train = y.loc[training_window_start:training_window_end]
    X_test = X.loc[training_window_end:]
    y_test = y.loc[training_window_end:]

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    model = SVC()
    model.fit(X_train_scaled, y_train)
    predictions = model.predict(X_test_scaled)

    df.loc[X_test.index, 'predicted_signal'] = predictions
    df['strategy_returns'] = df['actual_returns'] * df['predicted_signal'].shift()

    plt.figure(figsize=(10,6))
    plt.plot((1 + df['actual_returns'].loc[X_test.index]).cumprod(), label='Actual Returns', color='blue')
    plt.plot((1 + df['strategy_returns'].loc[X_test.index]).cumprod(), label='Strategy Returns', color='red')
    plt.legend()
    # Convert accuracy_str to a float and divide by 10000
    accuracy_percentage = float(accuracy_str) / 10000

    # Format as a percentage with 3 decimal places
    accuracy_percentage_str = f"{accuracy_percentage:.3%}"

    # Use the formatted string in the plot title
    plt.title(f"SVC Actual Returns vs. Strategy Returns\nShort Window: {short_window} | Long Window: {long_window} | Accuracy: {accuracy_percentage_str}")
    plt.xlabel("Date")
    plt.ylabel("Cumulative Returns")
    plt.xticks(rotation=45)
    plt.tight_layout()

    filename = f"{graphs_folder}/strategy_returns_svc_acc{accuracy_str}_svc_short{short_window}_long{long_window}.png"
    plt.savefig(filename)
    plt.close()
    print(f"Plot saved as {filename}")
# Out:
# Plot saved as Graphs/strategy_returns_acc08748_svc_short3_long67.png
# Plot saved as Graphs/strategy_returns_acc08717_svc_short3_long64.png
# Plot saved as Graphs/strategy_returns_acc08717_svc_short3_long59.png
# Plot saved as Graphs/strategy_returns_acc08498_svc_short12_long84.png
# Plot saved as Graphs/strategy_returns_acc08451_svc_short13_long84.png
# Plot saved as Graphs/strategy_returns_acc08435_svc_short7_long63.png
# Plot saved as Graphs/strategy_returns_acc08357_svc_short13_long115.png
# Plot saved as Graphs/strategy_returns_acc08326_svc_short4_long56.png
# Plot saved as Graphs/strategy_returns_acc08326_svc_short14_long94.png
# Plot saved as Graphs/strategy_returns_acc08279_svc_short9_long113.png
# Plot saved as Graphs/strategy_returns_acc08263_svc_short5_long134.png
# Plot saved as Graphs/strategy_returns_acc08263_svc_short13_long98.png
# Plot saved as Graphs/strategy_returns_acc08232_svc_short4_long133.png
# Plot saved as Graphs/strategy_returns_acc08232_svc_short13_long123.png
# Plot saved as Graphs/strategy_returns_acc08216_svc_short24_long128.png
# Plot saved as Graphs/strategy_returns_acc08200_svc_short12_long140.png
# Plot saved as Graphs/strategy_returns_acc08200_svc_short9_long140.png
# Plot saved as Graphs/strategy_returns_acc08200_svc_short13_long133.png
# Plot saved as Graphs/strategy_returns_acc08169_svc_short8_long138.png
# Plot saved as Graphs/strategy_returns_acc08153_svc_short5_long129.png

# %% [markdown]
# ---
#
# ## 1000 Tests - Optimizing SMA-Based Trading Strategies with AdaBoost Classifier
#
# This Python script employs the AdaBoost classification algorithm to evaluate the effectiveness of trading strategies based on Simple Moving Averages (SMA) over 1,000 random combinations of short and long window sizes. It operates on historical OHLCV (Open, High, Low, Close, Volume) data for emerging markets, loaded from a CSV file. The script dynamically calculates SMAs for each combination of window sizes, generates trading signals based on the crossover of short and long SMAs, and measures the strategy's accuracy in predicting market movements.
#
# After preprocessing the data, including scaling features to standardize the dataset, the AdaBoostClassifier model is trained and used to predict trading signals. The strategy's performance is evaluated based on the accuracy of these predictions against actual market movements. Each strategy's performance metrics, including the short window, long window, and accuracy, are recorded in a DataFrame, which is then sorted by accuracy in descending order to identify the most effective strategies.
#
# Finally, the script exports this sorted DataFrame to a CSV file, providing a comprehensive overview of the tested strategies' performances. This approach allows for an empirical assessment of various SMA-based trading strategies, leveraging machine learning to optimize decision-making in financial markets.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import AdaBoostClassifier  # Changed from SVC to Classifier
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
import random
import os
import warnings

with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=FutureWarning)
    # Assuming results_df is initialized earlier or this line is part of a loop

# Ensure correct parsing of the date format
df_original = pd.read_csv('Resources/emerging_markets_ohlcv.csv')
df_original['date'] = pd.to_datetime(df_original['date'], format='%m/%d/%y %H:%M')
df_original.set_index('date', inplace=True)

training_window_start = '2019-01-01'
training_window_end = '2020-01-01'

# Initialize a DataFrame to store the results
results_df = pd.DataFrame(columns=['Short Window', 'Long Window', 'Accuracy'])

for i in range(1000):
    short_window = random.randint(3, 138)
    long_window = random.randint(short_window + 1, 140)
    print(f"Trying window settings: short={short_window}, long={long_window}.")

    df = df_original.copy()
    df['short_mavg'] = df['close'].rolling(window=short_window, min_periods=1).mean()
    df['long_mavg'] = df['close'].rolling(window=long_window, min_periods=1).mean()
    df['signal'] = np.where(df['short_mavg'] > df['long_mavg'], 1, -1)
    df['actual_returns'] = df['close'].pct_change()
    df.dropna(inplace=True)

    if df.empty:
        print(f"Empty dataset for window settings: short={short_window}, long={long_window}. Skipping.")
        continue

    X = df[['short_mavg', 'long_mavg']]
    y = df['signal']
    X_train = X.loc[training_window_start:training_window_end]
    y_train = y.loc[training_window_start:training_window_end]
    X_test = X.loc[training_window_end:]
    y_test = y.loc[training_window_end:]

    if X_train.empty or X_test.empty:
        print("Empty training or testing set. Skipping.")
        continue

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Using AdaBoostClassifier
    model = AdaBoostClassifier()
    model.fit(X_train_scaled, y_train)
    predictions = model.predict(X_test_scaled)
    accuracy = accuracy_score(y_test, predictions)

    df.loc[X_test.index, 'predicted_signal'] = predictions
    df['strategy_returns'] = df['actual_returns'] * df['predicted_signal'].shift()

    # Append results to DataFrame using pd.concat
    new_row = pd.DataFrame({'Short Window': [short_window], 'Long Window': [long_window], 'Accuracy': [accuracy]})
    results_df = pd.concat([results_df, new_row], ignore_index=True)

# Sort the DataFrame by 'Accuracy' in descending order
sorted_results_df = results_df.sort_values(by='Accuracy', ascending=False)

# Export the sorted DataFrame to a CSV file
sorted_results_df.to_csv('strategy_results_adaboost_long_list.csv', index=False)
print("AdaBoost results summary saved to adaboost_strategy_adaboost_results_long_list.csv")
# Out:
# Trying window settings: short=31, long=116.
# Trying window settings: short=93, long=136.
# C:\Users\jan\AppData\Local\Temp\ipykernel_13836\761441004.py:68: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, new_row], ignore_index=True)
# Trying window settings: short=131, long=133.
# Trying window settings: short=119, long=126.
# Trying window settings: short=136, long=139.
# Trying window settings: short=18, long=68.
# Trying window settings: short=16, long=55.
# Trying window settings: short=44, long=97.
# Trying window settings: short=86, long=109.
# Trying window settings: short=138, long=140.
# Trying window settings: short=103, long=117.
# Trying window settings: short=19, long=105.
# Trying window settings: short=120, long=131.
# Trying window settings: short=111, long=130.
# Trying window settings: short=62, long=140.
# Trying window settings: short=17, long=69.
# Trying window settings: short=89, long=113.
# Trying window settings: short=115, long=127.
# Trying window settings: short=87, long=135.
# Trying window settings: short=62, long=67.
# Trying window settings: short=53, long=123.
# Trying window settings: short=91, long=97.
# Trying window settings: short=19, long=53.
# Trying window settings: short=107, long=132.
# Trying window settings: short=79, long=103.
# Trying window settings: short=94, long=129.
# Trying window settings: short=33, long=63.
# Trying window settings: short=120, long=139.
# Trying window settings: short=81, long=96.
# Trying window settings: short=25, long=37.
# Trying window settings: short=17, long=113.
# Trying window settings: short=89, long=91.
# Trying window settings: short=115, long=122.
# Trying window settings: short=95, long=130.
# Trying window settings: short=96, long=130.
# Trying window settings: short=98, long=110.
# Trying window settings: short=9, long=133.
# Trying window settings: short=122, long=133.
# Trying window settings: short=30, long=134.
# Trying window settings: short=32, long=44.
# Trying window settings: short=75, long=134.
# Trying window settings: short=52, long=119.
# Trying window settings: short=21, long=69.
# Trying window settings: short=61, long=104.
# Trying window settings: short=54, long=62.
# Trying window settings: short=83, long=122.
# Trying window settings: short=20, long=24.
# Trying window settings: short=33, long=41.
# Trying window settings: short=5, long=66.
# Trying window settings: short=43, long=128.
# Trying window settings: short=58, long=80.
# Trying window settings: short=88, long=93.
# Trying window settings: short=47, long=87.
# Trying window settings: short=11, long=132.
# Trying window settings: short=44, long=88.
# Trying window settings: short=85, long=116.
# Trying window settings: short=67, long=110.
# Trying window settings: short=130, long=136.
# Trying window settings: short=28, long=110.
# Trying window settings: short=102, long=133.
# Trying window settings: short=77, long=115.
# Trying window settings: short=48, long=135.
# Trying window settings: short=78, long=114.
# Trying window settings: short=104, long=124.
# Trying window settings: short=61, long=75.
# Trying window settings: short=5, long=110.
# Trying window settings: short=134, long=137.
# Trying window settings: short=114, long=136.
# Trying window settings: short=73, long=132.
# Trying window settings: short=114, long=128.
# Trying window settings: short=101, long=110.
# Trying window settings: short=86, long=96.
# Trying window settings: short=90, long=120.
# Trying window settings: short=114, long=122.
# Trying window settings: short=131, long=136.
# Trying window settings: short=133, long=138.
# Trying window settings: short=95, long=125.
# Trying window settings: short=9, long=119.
# Trying window settings: short=34, long=138.
# Trying window settings: short=116, long=134.
# Trying window settings: short=89, long=131.
# Trying window settings: short=6, long=82.
# Trying window settings: short=121, long=136.
# Trying window settings: short=15, long=55.
# Trying window settings: short=119, long=134.
# Trying window settings: short=121, long=132.
# Trying window settings: short=50, long=105.
# Trying window settings: short=32, long=101.
# Trying window settings: short=13, long=42.
# Trying window settings: short=30, long=98.
# Trying window settings: short=38, long=63.
# Trying window settings: short=45, long=71.
# Trying window settings: short=50, long=100.
# Trying window settings: short=135, long=138.
# Trying window settings: short=60, long=80.
# Trying window settings: short=122, long=129.
# Trying window settings: short=55, long=72.
# Trying window settings: short=107, long=140.
# Trying window settings: short=25, long=92.
# Trying window settings: short=131, long=134.
# Trying window settings: short=72, long=83.
# Trying window settings: short=69, long=119.
# Trying window settings: short=67, long=138.
# Trying window settings: short=62, long=140.
# Trying window settings: short=116, long=137.
# Trying window settings: short=122, long=126.
# Trying window settings: short=28, long=103.
# Trying window settings: short=24, long=81.
# Trying window settings: short=116, long=139.
# Trying window settings: short=51, long=55.
# Trying window settings: short=5, long=125.
# Trying window settings: short=72, long=131.
# Trying window settings: short=133, long=140.
# Trying window settings: short=71, long=73.
# Trying window settings: short=95, long=123.
# Trying window settings: short=82, long=89.
# Trying window settings: short=80, long=94.
# Trying window settings: short=62, long=95.
# Trying window settings: short=65, long=132.
# Trying window settings: short=135, long=140.
# Trying window settings: short=18, long=103.
# Trying window settings: short=15, long=50.
# Trying window settings: short=138, long=140.
# Trying window settings: short=115, long=123.
# Trying window settings: short=25, long=69.
# Trying window settings: short=26, long=57.
# Trying window settings: short=12, long=129.
# Trying window settings: short=36, long=106.
# Trying window settings: short=98, long=119.
# Trying window settings: short=136, long=137.
# Trying window settings: short=110, long=120.
# Trying window settings: short=129, long=136.
# Trying window settings: short=11, long=98.
# Trying window settings: short=40, long=43.
# Trying window settings: short=47, long=73.
# Trying window settings: short=79, long=139.
# Trying window settings: short=83, long=127.
# Trying window settings: short=13, long=95.
# Trying window settings: short=7, long=94.
# Trying window settings: short=16, long=89.
# Trying window settings: short=77, long=93.
# Trying window settings: short=8, long=113.
# Trying window settings: short=87, long=121.
# Trying window settings: short=3, long=89.
# Trying window settings: short=15, long=39.
# Trying window settings: short=99, long=114.
# Trying window settings: short=6, long=80.
# Trying window settings: short=59, long=62.
# Trying window settings: short=84, long=121.
# Trying window settings: short=98, long=140.
# Trying window settings: short=92, long=127.
# Trying window settings: short=30, long=66.
# Trying window settings: short=113, long=115.
# Trying window settings: short=9, long=28.
# Trying window settings: short=52, long=112.
# Trying window settings: short=3, long=138.
# Trying window settings: short=76, long=130.
# Trying window settings: short=98, long=138.
# Trying window settings: short=72, long=78.
# Trying window settings: short=109, long=122.
# Trying window settings: short=46, long=122.
# Trying window settings: short=133, long=136.
# Trying window settings: short=34, long=130.
# Trying window settings: short=31, long=120.
# Trying window settings: short=20, long=99.
# Trying window settings: short=37, long=67.
# Trying window settings: short=50, long=57.
# Trying window settings: short=128, long=137.
# Trying window settings: short=127, long=134.
# Trying window settings: short=97, long=109.
# Trying window settings: short=30, long=76.
# Trying window settings: short=72, long=84.
# Trying window settings: short=136, long=140.
# Trying window settings: short=103, long=104.
# Trying window settings: short=93, long=110.
# Trying window settings: short=95, long=120.
# Trying window settings: short=24, long=57.
# Trying window settings: short=106, long=139.
# Trying window settings: short=24, long=123.
# Trying window settings: short=116, long=137.
# Trying window settings: short=96, long=120.
# Trying window settings: short=12, long=78.
# Trying window settings: short=46, long=74.
# Trying window settings: short=58, long=139.
# Trying window settings: short=60, long=127.
# Trying window settings: short=71, long=121.
# Trying window settings: short=135, long=140.
# Trying window settings: short=54, long=68.
# Trying window settings: short=16, long=21.
# Trying window settings: short=57, long=79.
# Trying window settings: short=20, long=110.
# Trying window settings: short=16, long=108.
# Trying window settings: short=110, long=138.
# Trying window settings: short=70, long=104.
# Trying window settings: short=115, long=121.
# Trying window settings: short=136, long=137.
# Trying window settings: short=136, long=138.
# Trying window settings: short=99, long=138.
# Trying window settings: short=71, long=78.
# Trying window settings: short=18, long=95.
# Trying window settings: short=18, long=130.
# Trying window settings: short=132, long=136.
# Trying window settings: short=35, long=38.
# Trying window settings: short=20, long=31.
# Trying window settings: short=76, long=120.
# Trying window settings: short=81, long=125.
# Trying window settings: short=23, long=85.
# Trying window settings: short=105, long=121.
# Trying window settings: short=38, long=57.
# Trying window settings: short=83, long=128.
# Trying window settings: short=27, long=54.
# Trying window settings: short=26, long=124.
# Trying window settings: short=114, long=120.
# Trying window settings: short=73, long=99.
# Trying window settings: short=51, long=117.
# Trying window settings: short=96, long=132.
# Trying window settings: short=57, long=115.
# Trying window settings: short=80, long=82.
# Trying window settings: short=10, long=86.
# Trying window settings: short=76, long=119.
# Trying window settings: short=63, long=125.
# Trying window settings: short=60, long=95.
# Trying window settings: short=112, long=139.
# Trying window settings: short=16, long=117.
# Trying window settings: short=44, long=68.
# Trying window settings: short=3, long=24.
# Trying window settings: short=31, long=41.
# Trying window settings: short=115, long=126.
# Trying window settings: short=25, long=109.
# Trying window settings: short=38, long=47.
# Trying window settings: short=40, long=73.
# Trying window settings: short=105, long=132.
# Trying window settings: short=25, long=98.
# Trying window settings: short=32, long=120.
# Trying window settings: short=79, long=129.
# Trying window settings: short=60, long=104.
# Trying window settings: short=126, long=137.
# Trying window settings: short=25, long=78.
# Trying window settings: short=45, long=84.
# Trying window settings: short=123, long=126.
# Trying window settings: short=14, long=99.
# Trying window settings: short=65, long=119.
# Trying window settings: short=137, long=140.
# Trying window settings: short=12, long=15.
# Trying window settings: short=107, long=125.
# Trying window settings: short=118, long=119.
# Trying window settings: short=65, long=66.
# Trying window settings: short=30, long=74.
# Trying window settings: short=137, long=139.
# Trying window settings: short=122, long=127.
# Trying window settings: short=86, long=111.
# Trying window settings: short=127, long=140.
# Trying window settings: short=49, long=60.
# Trying window settings: short=93, long=119.
# Trying window settings: short=92, long=126.
# Trying window settings: short=90, long=112.
# Trying window settings: short=38, long=76.
# Trying window settings: short=123, long=131.
# Trying window settings: short=73, long=92.
# Trying window settings: short=134, long=136.
# Trying window settings: short=85, long=112.
# Trying window settings: short=76, long=105.
# Trying window settings: short=12, long=27.
# Trying window settings: short=7, long=123.
# Trying window settings: short=7, long=67.
# Trying window settings: short=77, long=98.
# Trying window settings: short=21, long=128.
# Trying window settings: short=94, long=114.
# Trying window settings: short=28, long=118.
# Trying window settings: short=28, long=76.
# Trying window settings: short=69, long=72.
# Trying window settings: short=65, long=92.
# Trying window settings: short=8, long=35.
# Trying window settings: short=23, long=42.
# Trying window settings: short=108, long=125.
# Trying window settings: short=44, long=67.
# Trying window settings: short=86, long=88.
# Trying window settings: short=128, long=136.
# Trying window settings: short=95, long=113.
# Trying window settings: short=78, long=131.
# Trying window settings: short=71, long=131.
# Trying window settings: short=99, long=131.
# Trying window settings: short=52, long=96.
# Trying window settings: short=44, long=108.
# Trying window settings: short=107, long=112.
# Trying window settings: short=106, long=123.
# Trying window settings: short=44, long=107.
# Trying window settings: short=131, long=140.
# Trying window settings: short=118, long=120.
# Trying window settings: short=82, long=136.
# Trying window settings: short=30, long=63.
# Trying window settings: short=104, long=122.
# Trying window settings: short=30, long=35.
# Trying window settings: short=54, long=120.
# Trying window settings: short=38, long=86.
# Trying window settings: short=117, long=136.
# Trying window settings: short=129, long=139.
# Trying window settings: short=8, long=63.
# Trying window settings: short=94, long=127.
# Trying window settings: short=131, long=135.
# Trying window settings: short=129, long=130.
# Trying window settings: short=89, long=116.
# Trying window settings: short=71, long=83.
# Trying window settings: short=55, long=92.
# Trying window settings: short=103, long=123.
# Trying window settings: short=99, long=112.
# Trying window settings: short=43, long=87.
# Trying window settings: short=44, long=113.
# Trying window settings: short=104, long=119.
# Trying window settings: short=85, long=109.
# Trying window settings: short=46, long=121.
# Trying window settings: short=18, long=51.
# Trying window settings: short=32, long=67.
# Trying window settings: short=98, long=110.
# Trying window settings: short=81, long=83.
# Trying window settings: short=120, long=126.
# Trying window settings: short=28, long=43.
# Trying window settings: short=56, long=78.
# Trying window settings: short=111, long=121.
# Trying window settings: short=8, long=130.
# Trying window settings: short=72, long=129.
# Trying window settings: short=71, long=88.
# Trying window settings: short=119, long=136.
# Trying window settings: short=39, long=106.
# Trying window settings: short=72, long=85.
# Trying window settings: short=96, long=125.
# Trying window settings: short=31, long=132.
# Trying window settings: short=38, long=41.
# Trying window settings: short=122, long=126.
# Trying window settings: short=125, long=131.
# Trying window settings: short=75, long=123.
# Trying window settings: short=130, long=136.
# Trying window settings: short=66, long=101.
# Trying window settings: short=40, long=136.
# Trying window settings: short=37, long=65.
# Trying window settings: short=84, long=95.
# Trying window settings: short=110, long=135.
# Trying window settings: short=34, long=89.
# Trying window settings: short=25, long=103.
# Trying window settings: short=98, long=138.
# Trying window settings: short=83, long=92.
# Trying window settings: short=45, long=108.
# Trying window settings: short=114, long=137.
# Trying window settings: short=15, long=128.
# Trying window settings: short=24, long=129.
# Trying window settings: short=135, long=137.
# Trying window settings: short=34, long=71.
# Trying window settings: short=115, long=126.
# Trying window settings: short=23, long=41.
# Trying window settings: short=133, long=140.
# Trying window settings: short=21, long=65.
# Trying window settings: short=30, long=139.
# Trying window settings: short=27, long=122.
# Trying window settings: short=76, long=124.
# Trying window settings: short=40, long=53.
# Trying window settings: short=103, long=125.
# Trying window settings: short=135, long=137.
# Trying window settings: short=121, long=125.
# Trying window settings: short=53, long=96.
# Trying window settings: short=109, long=128.
# Trying window settings: short=134, long=137.
# Trying window settings: short=88, long=130.
# Trying window settings: short=71, long=102.
# Trying window settings: short=96, long=123.
# Trying window settings: short=119, long=133.
# Trying window settings: short=81, long=105.
# Trying window settings: short=24, long=66.
# Trying window settings: short=96, long=136.
# Trying window settings: short=30, long=78.
# Trying window settings: short=61, long=99.
# Trying window settings: short=58, long=119.
# Trying window settings: short=29, long=36.
# Trying window settings: short=133, long=138.
# Trying window settings: short=22, long=45.
# Trying window settings: short=85, long=139.
# Trying window settings: short=38, long=63.
# Trying window settings: short=43, long=93.
# Trying window settings: short=73, long=120.
# Trying window settings: short=71, long=125.
# Trying window settings: short=121, long=138.
# Trying window settings: short=37, long=125.
# Trying window settings: short=93, long=108.
# Trying window settings: short=67, long=139.
# Trying window settings: short=40, long=59.
# Trying window settings: short=136, long=139.
# Trying window settings: short=45, long=118.
# Trying window settings: short=7, long=23.
# Trying window settings: short=53, long=119.
# Trying window settings: short=60, long=82.
# Trying window settings: short=117, long=123.
# Trying window settings: short=18, long=24.
# Trying window settings: short=108, long=130.
# Trying window settings: short=26, long=71.
# Trying window settings: short=131, long=133.
# Trying window settings: short=137, long=139.
# Trying window settings: short=43, long=96.
# Trying window settings: short=97, long=123.
# Trying window settings: short=69, long=118.
# Trying window settings: short=122, long=126.
# Trying window settings: short=123, long=133.
# Trying window settings: short=37, long=119.
# Trying window settings: short=8, long=127.
# Trying window settings: short=137, long=138.
# Trying window settings: short=106, long=129.
# Trying window settings: short=43, long=58.
# Trying window settings: short=121, long=123.
# Trying window settings: short=26, long=60.
# Trying window settings: short=90, long=92.
# Trying window settings: short=67, long=132.
# Trying window settings: short=55, long=67.
# Trying window settings: short=110, long=131.
# Trying window settings: short=34, long=44.
# Trying window settings: short=35, long=102.
# Trying window settings: short=14, long=74.
# Trying window settings: short=111, long=131.
# Trying window settings: short=129, long=137.
# Trying window settings: short=23, long=107.
# Trying window settings: short=123, long=129.
# Trying window settings: short=21, long=60.
# Trying window settings: short=12, long=71.
# Trying window settings: short=60, long=138.
# Trying window settings: short=110, long=129.
# Trying window settings: short=22, long=105.
# Trying window settings: short=133, long=138.
# Trying window settings: short=64, long=65.
# Trying window settings: short=115, long=128.
# Trying window settings: short=87, long=108.
# Trying window settings: short=99, long=117.
# Trying window settings: short=42, long=114.
# Trying window settings: short=91, long=95.
# Trying window settings: short=122, long=125.
# Trying window settings: short=79, long=116.
# Trying window settings: short=134, long=140.
# Trying window settings: short=129, long=137.
# Trying window settings: short=72, long=124.
# Trying window settings: short=65, long=74.
# Trying window settings: short=61, long=106.
# Trying window settings: short=53, long=102.
# Trying window settings: short=67, long=102.
# Trying window settings: short=133, long=134.
# Trying window settings: short=98, long=136.
# Trying window settings: short=93, long=130.
# Trying window settings: short=129, long=131.
# Trying window settings: short=98, long=104.
# Trying window settings: short=86, long=104.
# Trying window settings: short=75, long=113.
# Trying window settings: short=77, long=102.
# Trying window settings: short=11, long=39.
# Trying window settings: short=18, long=117.
# Trying window settings: short=25, long=67.
# Trying window settings: short=105, long=108.
# Trying window settings: short=49, long=72.
# Trying window settings: short=50, long=55.
# Trying window settings: short=127, long=134.
# Trying window settings: short=110, long=114.
# Trying window settings: short=96, long=128.
# Trying window settings: short=99, long=121.
# Trying window settings: short=96, long=99.
# Trying window settings: short=51, long=106.
# Trying window settings: short=41, long=105.
# Trying window settings: short=81, long=84.
# Trying window settings: short=36, long=94.
# Trying window settings: short=3, long=69.
# Trying window settings: short=86, long=90.
# Trying window settings: short=43, long=104.
# Trying window settings: short=60, long=109.
# AdaBoost results summary saved to adaboost_strategy_adaboost_results_long_list.csv
